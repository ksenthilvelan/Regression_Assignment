# %%
import pandas as p

# %%
dataset=p.read_csv("Insurance_pre.csv")
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=p.get_dummies(dataset,drop_first=True)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
dependent=dataset[['charges']]
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(independent,dependent,test_size=0.30,random_state=0)

# %%
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
regressor=RandomForestRegressor(criterion='mae',max_depth=None,n_estimators=50,random_state=0,max_features=None)
regressor.fit(x_train,y_train)
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   This is separate from the ipykernel package so we can avoid doing imports until
# RandomForestRegressor(bootstrap=True, criterion='mae', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=50,
#                       n_jobs=None, oob_score=False, random_state=0, verbose=0,
#                       warm_start=False)

# %%
x_test
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 578    52  30.200         1         1           0
# 610    47  29.370         1         0           0
# 569    48  40.565         2         1           1
# 1034   61  38.380         0         1           0
# 198    51  18.050         0         0           0
# ...   ...     ...       ...       ...         ...
# 1261   28  37.100         1         1           0
# 494    21  25.700         4         1           1
# 97     55  38.280         0         1           0
# 418    64  39.160         1         1           0
# 920    62  25.000         0         0           0
#
# [402 rows x 5 columns]

# %%
y_pred=regressor.predict(x_test)
y_pred
# Out:
# array([10622.818165 ,  9071.0114612, 44361.913815 , 13193.7982905,
#        10069.3459518, 11074.4522838,  2626.748873 , 10771.84343  ,
#         7096.609183 ,  6717.809267 ,  7568.870404 , 20259.044217 ,
#         7279.85649  ,  5981.7687158, 25153.462821 , 15037.9284866,
#        14699.9844434,  3248.006143 ,  6378.571055 , 33968.049384 ,
#        23797.820154 , 12486.4490972, 11827.6634276, 26211.7727454,
#         1739.201236 ,  8421.86941  ,  4903.8809378,  8366.3431658,
#         3690.062249 ,  9383.4619952,  8834.1257422, 48260.716448 ,
#        13115.377761 , 12977.6774414, 15538.8710916,  3682.785637 ,
#         8762.585501 , 38083.9763516, 39353.57359  ,  1907.671564 ,
#         6566.4788248,  3467.4515286, 22772.4654414, 47833.0504262,
#        37692.1911162,  3632.6408268, 15046.2210146,  6830.646881 ,
#         7164.9477642, 12352.7446544,  7100.330482 ,  3704.714604 ,
#        25777.724007 , 48271.80464  , 11803.582356 , 13958.0470418,
# ...

# %%
from sklearn.metrics import r2_score
r_score = r2_score(y_test,y_pred)
r_score
# Out:
# 0.8521864171787733

# %%
import pickle
filename="RandomForest_Model.sav"
pickle.dump(regressor,open(filename,'wb'))

# %%
loaded_model=pickle.load(open("RandomForest_Model.sav","rb"))
input
result=loaded_model.predict([[1342,1245,1412,1,0]])
result
# Out:
# array([31450.0675846])
